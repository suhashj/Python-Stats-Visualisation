# %% [markdown]
# # Seaborn Histogram and seaborn Distplot

# %%
#Import libaries

import seaborn as sns # for data visualization
import pandas as pd # for data analysis
import matplotlib.pyplot as plt # for data visualization

# %%
#Load "tips" DataFrame from GitHub seaborn repository
tips_df = sns.load_dataset("tips")
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips_df.shape
# Out:
# (244, 7)

# %% [raw]
# Here we are using Sns.distplot for histogram in seaborn
#
# In matplotlib we are using plt.hist for histogram

# %% [raw]
# Here along with histogram we will get line plot i.e kde (Kernel density estimator)

# %%
#Plot Histogram of "size"

sns.distplot(tips_df["size"])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='size', ylabel='Density'>

# %% [raw]
#  In above graph to remove this line <matplotlib.axes._subplots.AxesSubplot at 0xecbfbe0af0>
#
# Then use plt.show()

# %%
#Plot Histogram of "size"
sns.distplot(tips_df["size"],hist=False)
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Plot Histogram of "tip"

sns.distplot(tips_df["tip"])
plt.show()

# %%
#Plot Histogram of "total_bill"
sns.distplot(tips_df["total_bill"])
plt.show()

# %% [markdown]
# # All parameters of Seaborn distplot

# %%
"""
sns.distplot(
    a,
    bins=None,
    hist=True,
    kde=True,
    rug=False,
    fit=None,
    hist_kws=None,
    kde_kws=None,
    rug_kws=None,
    fit_kws=None,
    color=None,
    vertical=False,
    norm_hist=False,
    axlabel=None,
    label=None,
    ax=None,
)
"""
# Out:
# '\nsns.distplot(\n    a,\n    bins=None,\n    hist=True,\n    kde=True,\n    rug=False,\n    fit=None,\n    hist_kws=None,\n    kde_kws=None,\n    rug_kws=None,\n    fit_kws=None,\n    color=None,\n    vertical=False,\n    norm_hist=False,\n    axlabel=None,\n    label=None,\n    ax=None,\n)\n'

# %% [markdown]
# # use bins parameter

# %%
#Plot Histogram of "total_bill" with bins parameters

sns.distplot(tips_df["total_bill"], bins=55)
plt.show()

# %%
#Plot Histogram of "total_bill" with bins parameters
sns.distplot(tips_df["total_bill"], bins=100)

# %% [markdown]
# # use hist parameter

# %% [raw]
# by deafualt hist is True , now change it to False , then we will observe that histogram will not be visible only line plot (kde will be visible)

# %%
#Plot Histogram of "total_bill" with hist parameters

sns.distplot(tips_df["total_bill"], hist = False)
plt.show()

# %% [raw]
# use kde parameter by defauly kde is True , now change to False , then we will observe that line plot will not be visible only histogram will be visible

# %%
#Plot Histogram of "total_bill" with kde (kernal density estimator) parameters
sns.distplot(tips_df["total_bill"], kde=False)
plt.show()

# %% [markdown]
# # Use rug parameter

# %% [raw]
# in x axis we will get some dark line which shows that in x axis from where it will start

# %%
#Plot Histogram of "total_bill" with rugplot parameters
sns.distplot(tips_df["total_bill"],rug=True)
plt.show()

# %% [markdown]
# # use fit and kde parameter

# %% [raw]
# fit= norm indiacates it will kde in normalised plot

# %%
#Plot Histogram of "total_bill" with fit and kde parameters
sns.distplot(tips_df["total_bill"],fit=norm, kde = False) # for fit (prm) -  from scipy.stats import norm

# %%
from scipy.stats import norm

# %%
#Plot Histogram of "total_bill" with fit and kde parameters

sns.distplot(tips_df["total_bill"],fit=norm, kde = False)
plt.show()

# %% [markdown]
# # use color parameter

# %% [raw]
# color parametr will change the color

# %%
#Plot Histogram of "total_bill" with color parameters
sns.distplot(tips_df["total_bill"],color="r",)
plt.show()

# %% [markdown]
# # Use Vertical Parameter

# %%
#Plot Histogram of "total_bill" with vertical parameters
sns.distplot(tips_df["total_bill"],vertical=True,)
plt.show()

# %% [markdown]
# # use normhist parameter

# %%
#Plot Histogram of "total_bill" with norm_hist parameters
sns.distplot(tips_df["total_bill"],norm_hist=True)
plt.show()

# %% [markdown]
# # use axlabel parameter

# %% [raw]
# To change x axis label name then use axlabel

# %%
#Plot Histogram of "total_bill" with axlabel parameters
sns.distplot(tips_df["total_bill"],axlabel="Total Bill")
plt.show()

# %% [markdown]
# # use legend parameter

# %%
#Plot Histogram of "total_bill" with label parameters
sns.distplot(tips_df["total_bill"],label="Total Bill")
plt.legend()
plt.show()

# %%
#Plot Histogram of "total_bill" with label parameters
sns.distplot(tips_df["total_bill"],label="Total Bill",)

plt.title("Histogram of Total Bill") # for histogram title
plt.legend() # for label
plt.show()
